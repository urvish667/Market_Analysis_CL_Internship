# %% [markdown]
# # Module 2- Plotting in Financial Markets

# %% [markdown]
#    ### Welcome to the Answer notebook for Module 2 !
# Make sure that you've submitted the module 1 notebook and unlocked Module 2 yourself before you start coding here

# %% [markdown]
# #--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------#

# %% [markdown]
# ### Query 2.1
# Load the week2.csv file into a dataframe. What is the type of the Date column? Make sure it is of type datetime64. Convert the Date column to the index of the dataframe.
# Plot the closing price of each of the days for the entire time frame to get an idea of what the general outlook of the stock is.
#
# >Look out for drastic changes in this stock, you have the exact date when these took place, try to fetch the news for this day of this stock
#
# >This would be helpful if we are to train our model to take NLP inputs.

# %%
import pandas as pd
import numpy as np
from datetime import datetime
from functools import partial

# %%
df = pd.read_csv("week2.csv")#loading week2.csv file
del df['Unnamed: 0']
duplicate_data = df 
df.head()
# Out:
#       Symbol Series        Date  Prev Close  Open Price  High Price  \
# 0  EICHERMOT     EQ  2017-05-15    29178.35    29403.10    29455.00
# 1  EICHERMOT     EQ  2017-05-16    28930.60    28920.45    29450.00
# 2  EICHERMOT     EQ  2017-05-17    29362.50    29262.00    29300.00
# 3  EICHERMOT     EQ  2017-05-18    29093.55    28900.00    28998.85
# 4  EICHERMOT     EQ  2017-05-19    28357.30    28698.00    28698.00
#
#    Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0   28831.00    28915.05     28930.60       29015.64                  20026
# 1   28820.00    29365.95     29362.50       29107.91                  36189
# 2   28971.35    28982.05     29093.55       29116.26                  18545
# 3   28213.00    28213.00     28357.30       28521.49                  30153
# 4   27756.00    27915.00     27936.05       28024.04                  44251
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty  \
# ...

# %%
#df['Date'] = pd.to_datetime(df['Date'])
df.Date.dtype
df.set_index('Date', inplace = True)

# %%
# %matplotlib inline

import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
df['Close Price'].plot(label = 'EICHER', figsize=(16,8),title='Closing Price with respect to Date')
plt.legend()

# %%
df['Close Price'].diff().abs().sort_values(ascending = False)
# Out:
# Date
# 2018-09-24    2087.40
# 2019-01-02    2032.80
# 2019-05-13    1602.25
# 2018-08-10    1558.95
# 2019-03-05    1556.75
# 2018-10-12    1546.30
# 2018-10-03    1513.75
# 2018-10-10    1496.65
# 2017-08-01    1423.60
# 2017-08-10    1377.40
# 2018-10-04    1327.90
# 2018-11-13    1308.30
# 2017-11-01    1303.60
# 2018-01-02    1223.00
# 2018-02-01    1123.75
# 2019-01-29    1110.15
# 2019-03-11    1101.40
# 2018-12-12    1081.40
# 2019-02-08    1056.80
# 2018-10-09    1049.05
# 2017-09-29    1028.10
# 2018-10-17    1024.05
# 2018-02-16    1012.30
# 2019-02-13     978.80
# 2018-07-26     977.35
# 2018-03-20     957.40
# 2019-01-03     950.85
# 2018-10-08     944.30
# 2018-04-04     944.25
# 2018-01-29     934.25
#                ...
# 2019-01-14      27.20
# 2019-04-10      26.65
# 2019-01-24      26.45
# 2017-06-16      25.10
# 2018-07-23      24.65
# 2019-04-11      24.40
# 2019-05-09      24.35
# 2018-03-26      23.05
# 2017-06-08      22.15
# 2017-09-04      18.85
# ...

# %%
plt.figure(figsize=(20,10))
plt.stem(df['Day_Perc_Change'])
# Out:
# <StemContainer object of 3 artists>

# %%
plt.figure(figsize=(20,10))
plt.stem(df['Total Traded Quantity'])
# Out:
# <StemContainer object of 3 artists>

# %%
plt.figure(figsize=(20,10))
plt.stem(df['Total Traded Quantity'])
plt.show()
plt.figure(figsize=(20,10))
plt.stem(df['Day_Perc_Change'])
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.stem(df['Day_Perc_Change'],df['Total Traded Quantity'])
plt.show()
plt.figure(figsize=(20,10))
plt.stem(df['Total Traded Quantity'],df['Day_Perc_Change'])
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.plot(df['Day_Perc_Change'],df['Total Traded Quantity'])
plt.show()
plt.figure(figsize=(20,10))
plt.plot(df['Total Traded Quantity'],df['Day_Perc_Change'])
plt.show()

# %%
import matplotlib.pyplot as plt
from collections import Counter

Trends = ['Postive','Negative','Breakout Bull','Breakout Bear','Among top losers','Among top gainers','Slight or No Change','Slight Positive','Slight Negative']
Trend_to_list = df['Trend'].tolist()
counts = Counter(Trend_to_list)
counts
# Out:
# Counter({'Slight or No change': 494})

# %%
counter = [494]
labels= ['Slight or No change']
colors = ['r']
plt.figure(figsize=(20,10))
plt.pie(counter, labels=labels,colors=colors,startangle=90, autopct='%.1f%%')
plt.show()

# %%
group = df.groupby(['Trend'])['Total Traded Quantity']

# %%
plt.figure(figsize=(20,10))
df.groupby(['Trend'])['Total Traded Quantity'].mean().plot.bar()

# %%
plt.figure(figsize=(20,10))
df.groupby(['Trend'])['Total Traded Quantity'].median().plot.bar()

# %%
plt.figure(figsize=(20,10))
plt.hist(df['Day_Perc_Change'])
plt.show()

# %%
adaniports_data = pd.read_csv('ADANIPORTS.csv')
reliance_data = pd.read_csv('RELIANCE.csv')
tcs_data = pd.read_csv('TCS.csv')
titan_data = pd.read_csv('TITAN.csv')
voltas_data = pd.read_csv('VOLTAS.csv')

# %%
adaniports_data
# Out:
#          Symbol Series         Date  Prev Close  Open Price  High Price  \
# 0    ADANIPORTS     EQ  15-May-2017      357.95      359.00      359.75
# 1    ADANIPORTS     EQ  16-May-2017      356.20      354.20      358.15
# 2    ADANIPORTS     EQ  17-May-2017      354.50      354.50      354.80
# 3    ADANIPORTS     EQ  18-May-2017      348.55      344.30      359.55
# 4    ADANIPORTS     EQ  19-May-2017      347.90      349.05      352.50
# 5    ADANIPORTS     EQ  22-May-2017      349.45      352.40      357.40
# 6    ADANIPORTS     EQ  23-May-2017      354.45      354.80      355.60
# 7    ADANIPORTS     EQ  24-May-2017      331.65      333.40      342.95
# 8    ADANIPORTS     EQ  25-May-2017      339.65      344.90      346.25
# 9    ADANIPORTS     EQ  26-May-2017      340.75      342.40      351.00
# 10   ADANIPORTS     EQ  29-May-2017      348.00      347.80      348.35
# 11   ADANIPORTS     EQ  30-May-2017      327.80      328.40      342.90
# ...

# %%
reliance_data
# Out:
#        Symbol Series         Date  Prev Close  Open Price  High Price  \
# 0    RELIANCE     EQ  15-May-2017     1350.45     1356.40     1356.40
# 1    RELIANCE     EQ  16-May-2017     1344.10     1346.05     1376.90
# 2    RELIANCE     EQ  17-May-2017     1356.30     1353.00     1365.95
# 3    RELIANCE     EQ  18-May-2017     1353.10     1340.25     1350.00
# 4    RELIANCE     EQ  19-May-2017     1327.35     1333.00     1335.70
# 5    RELIANCE     EQ  22-May-2017     1318.85     1326.50     1333.60
# 6    RELIANCE     EQ  23-May-2017     1324.15     1325.70     1329.85
# 7    RELIANCE     EQ  24-May-2017     1305.55     1307.50     1313.70
# 8    RELIANCE     EQ  25-May-2017     1297.70     1300.00     1312.40
# 9    RELIANCE     EQ  26-May-2017     1302.45     1303.95     1344.40
# 10   RELIANCE     EQ  29-May-2017     1337.30     1337.00     1365.45
# 11   RELIANCE     EQ  30-May-2017     1356.90     1355.90     1364.70
# ...

# %%
tcs_data
# Out:
#     Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 0      TCS     EQ  15-May-2017     2360.65     2375.10     2377.95    2341.60
# 1      TCS     EQ  16-May-2017     2365.10     2380.00     2435.00    2373.45
# 2      TCS     EQ  17-May-2017     2429.15     2433.50     2460.75    2423.00
# 3      TCS     EQ  18-May-2017     2455.35     2450.00     2572.00    2442.25
# 4      TCS     EQ  19-May-2017     2536.20     2536.20     2540.55    2486.00
# 5      TCS     EQ  22-May-2017     2507.15     2510.00     2553.75    2510.00
# 6      TCS     EQ  23-May-2017     2531.35     2533.20     2564.15    2514.00
# 7      TCS     EQ  24-May-2017     2521.70     2534.80     2570.00    2529.65
# 8      TCS     EQ  25-May-2017     2559.15     2577.00     2637.55    2568.00
# 9      TCS     EQ  26-May-2017     2624.60     2625.00     2626.85    2564.65
# 10     TCS     EQ  29-May-2017     2578.25     2579.00     2596.50    2564.00
# ...

# %%
titan_data
# Out:
#     Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 0    TITAN     EQ  15-May-2017      495.00      489.65      490.00     472.40
# 1    TITAN     EQ  16-May-2017      483.65      486.00      491.00     480.80
# 2    TITAN     EQ  17-May-2017      488.30      490.00      490.10     477.30
# 3    TITAN     EQ  18-May-2017      481.75      479.00      482.60     470.05
# 4    TITAN     EQ  19-May-2017      471.65      475.00      479.50     460.35
# 5    TITAN     EQ  22-May-2017      471.15      474.00      483.75     472.20
# 6    TITAN     EQ  23-May-2017      481.40      478.65      485.60     472.95
# 7    TITAN     EQ  24-May-2017      478.35      474.25      478.95     460.10
# 8    TITAN     EQ  25-May-2017      469.20      471.10      471.85     461.00
# 9    TITAN     EQ  26-May-2017      463.90      464.80      477.95     462.90
# 10   TITAN     EQ  29-May-2017      473.45      471.80      494.15     469.00
# ...

# %%
voltas_data
# Out:
#      Symbol Series         Date  Prev Close  Open Price  High Price  \
# 0    VOLTAS     EQ  15-May-2017      433.55      436.00      436.40
# 1    VOLTAS     EQ  16-May-2017      431.85      432.00      438.20
# 2    VOLTAS     EQ  17-May-2017      432.45      435.00      435.00
# 3    VOLTAS     EQ  18-May-2017      430.20      425.10      427.00
# 4    VOLTAS     EQ  19-May-2017      414.10      414.35      419.90
# 5    VOLTAS     EQ  22-May-2017      415.75      420.00      420.00
# 6    VOLTAS     EQ  23-May-2017      415.65      420.00      420.00
# 7    VOLTAS     EQ  24-May-2017      409.85      428.00      450.80
# 8    VOLTAS     EQ  25-May-2017      446.50      451.00      484.00
# 9    VOLTAS     EQ  26-May-2017      474.75      470.10      501.75
# 10   VOLTAS     EQ  29-May-2017      498.50      496.90      499.75
# 11   VOLTAS     EQ  30-May-2017      484.60      481.60      491.00
# 12   VOLTAS     EQ  31-May-2017      485.60      485.60      494.00
# ...

# %%
adaniports = adaniports_data[adaniports_data.Series == 'EQ']
reliance = reliance_data[reliance_data.Series == 'EQ']
tcs = tcs_data[tcs_data.Series == 'EQ']
titan = titan_data[titan_data.Series == 'EQ']
voltas = voltas_data[voltas_data.Series == 'EQ']

# %%
cols = ['ADANIPORTS','RELIANCE','TCS','TITAN','VOLTAS']
close_prices = pd.DataFrame(columns = cols)

# %%
close_prices = pd.DataFrame(columns = cols)
close_prices['ADANIPORTS'] = adaniports['Close Price']
close_prices['RELIANCE'] = reliance['Close Price']
close_prices['TCS'] = tcs['Close Price']
close_prices['TITAN'] = titan['Close Price']
close_prices['VOLTAS'] = voltas['Close Price']
close_prices.dropna()
# Out:
#      ADANIPORTS  RELIANCE      TCS    TITAN  VOLTAS
# 0        356.20   1344.10  2365.10   483.65  431.85
# 1        354.50   1356.30  2429.15   488.30  432.45
# 2        348.55   1353.10  2455.35   481.75  430.20
# 3        347.90   1327.35  2536.20   471.65  414.10
# 4        349.45   1318.85  2507.15   471.15  415.75
# 5        354.45   1324.15  2531.35   481.40  415.65
# 6        331.65   1305.55  2521.70   478.35  409.85
# 7        339.65   1297.70  2559.15   469.20  446.50
# 8        340.75   1302.45  2624.60   463.90  474.75
# 9        348.00   1337.30  2578.25   473.45  498.50
# 10       327.80   1356.90  2572.85   470.65  484.60
# 11       340.35   1359.35  2551.10   469.80  485.60
# 12       339.00   1340.70  2546.60   474.90  486.35
# 13       349.20   1328.25  2553.60   470.70  508.85
# 14       357.90   1324.75  2564.90   471.75  500.45
# 15       361.05   1329.35  2603.95   551.85  494.95
# 16       361.45   1312.80  2696.00   527.15  487.00
# ...

# %%
pct_change = close_prices.pct_change().fillna(0)
pct_change.dropna()
# Out:
#      ADANIPORTS  RELIANCE       TCS     TITAN    VOLTAS
# 0      0.000000  0.000000  0.000000  0.000000  0.000000
# 1     -0.004773  0.009077  0.027081  0.009614  0.001389
# 2     -0.016784 -0.002359  0.010786 -0.013414 -0.005203
# 3     -0.001865 -0.019030  0.032928 -0.020965 -0.037424
# 4      0.004455 -0.006404 -0.011454 -0.001060  0.003985
# 5      0.014308  0.004019  0.009652  0.021755 -0.000241
# 6     -0.064325 -0.014047 -0.003812 -0.006336 -0.013954
# 7      0.024122 -0.006013  0.014851 -0.019128  0.089423
# 8      0.003239  0.003660  0.025575 -0.011296  0.063270
# 9      0.021277  0.026757 -0.017660  0.020586  0.050026
# 10    -0.058046  0.014656 -0.002094 -0.005914 -0.027884
# 11     0.038286  0.001806 -0.008454 -0.001806  0.002064
# 12    -0.003967 -0.013720 -0.001764  0.010856  0.001544
# 13     0.030088 -0.009286  0.002749 -0.008844  0.046263
# 14     0.024914 -0.002635  0.004425  0.002231 -0.016508
# 15     0.008801  0.003472  0.015225  0.169793 -0.010990
# ...

# %%
import seaborn as sns

sns.set(color_codes=True)
sns.pairplot(pct_change)

# %%
roll_adaniports = pct_change['ADANIPORTS'].rolling(7).mean()
roll_adaniports
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6     -0.009855
# 7     -0.006409
# 8     -0.005264
# 9      0.000173
# 10    -0.007853
# 11    -0.003020
# 12    -0.005631
# 13     0.007857
# 14     0.007970
# 15     0.008765
# 16     0.005884
# 17     0.013247
# 18     0.007798
# 19     0.008643
# 20     0.003153
# 21     0.000615
# 22    -0.000603
# 23    -0.000562
# 24     0.001617
# 25     0.005786
# 26     0.006215
# 27     0.005238
# 28     0.004024
# 29     0.002438
#          ...
# 465   -0.000259
# 466    0.004852
# 467    0.004930
# 468    0.008793
# 469    0.007484
# 470    0.008112
# 471    0.004572
# 472    0.008075
# 473   -0.000450
# 474    0.001031
# 475    0.000212
# 476   -0.000029
# 477    0.001440
# 478    0.002632
# 479    0.003194
# 480    0.004028
# 481    0.003910
# 482    0.002823
# 483    0.004624
# 484    0.001378
# 485    0.001777
# 486   -0.001014
# 487    0.001737
# 488   -0.001355
# ...

# %%
std_adaniports = roll_adaniports.fillna(0).std()
std_adaniports
# Out:
# 0.0066475515323852164

# %%
crr_date = pd.to_datetime(adaniports['Date'])
crr_list = crr_date.tolist()
plt.figure(figsize=(20,10))
plt.plot(crr_list,roll_adaniports.fillna(0).tolist())
plt.show()

# %%
nifty = pd.read_csv("Nifty50.csv")
nifty
# Out:
#             Date      Open      High       Low     Close  Shares Traded  \
# 0    15-May-2017   9433.55   9449.25   9423.10   9445.40      145163953
# 1    16-May-2017   9461.00   9517.20   9456.35   9512.25      171709433
# 2    17-May-2017   9517.60   9532.60   9486.10   9525.75      211856040
# 3    18-May-2017   9453.20   9489.10   9418.10   9429.45      199340647
# 4    19-May-2017   9469.90   9505.75   9390.75   9427.90      259861396
# 5    22-May-2017   9480.25   9498.65   9427.90   9438.25      202874757
# 6    23-May-2017   9445.05   9448.05   9370.00   9386.15      231345629
# 7    24-May-2017   9410.90   9431.90   9341.65   9360.55      218265181
# 8    25-May-2017   9384.05   9523.30   9379.20   9509.75      298147347
# 9    26-May-2017   9507.75   9604.90   9495.40   9595.10      225647631
# 10   29-May-2017   9560.05   9637.75   9547.70   9604.90      242266034
# 11   30-May-2017   9590.65   9635.30   9581.20   9624.55      199894193
# ...

# %%
nif_close_price = nifty['Close']
nif_change = nif_close_price.pct_change().fillna(0).rolling(7).mean().fillna(0)
nifDate = pd.to_datetime(nifty['Date'])
nifDate = nifDate.tolist()
plt.figure(figsize=(20,10))

voltas_date = pd.to_datetime(voltas['Date'])
voltas_list = voltas_date.tolist()
voltas_close_price = voltas['Close Price']
voltas_change = voltas_close_price.pct_change().fillna(0).rolling(7).mean().fillna(0)
plt.figure(figsize=(20,10))
plt.plot(voltas_list,roll_adaniports.fillna(0).tolist())

plt.title("Volatility of NIFTY with respect to voltas and adaniports")
plt.plot(nifDate,nif_change.tolist(),label = 'nifty')
plt.plot(crr_list,roll_adaniports.fillna(0).tolist(),label = 'adaniports')
plt.plot(voltas_list,voltas_change,label = 'voltas')
plt.legend(loc='upper left')
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.plot(voltas_list,voltas_change,label = 'voltas')
plt.legend(loc='upper left')
plt.show()

# %%
short_window = 21
long_window = 34

signals = pd.DataFrame(index=voltas.index)
signals['signal'] = 0.0

signals['short_mavg'] = voltas['Close Price'].rolling(window=short_window, min_periods=1,center=False).mean()

signals['long_mavg'] = voltas['Close Price'].rolling(window=long_window,min_periods=1, center=False).mean()

signals['signal'][short_window:] = np.where(signals['short_mavg'][short_window:] > signals['long_mavg'][short_window:], 1.0,0.0)

signals['positions'] = signals['signal'].diff()
print(signals)
# Out:
#      signal  short_mavg   long_mavg  positions
# 0       0.0  431.850000  431.850000        NaN
# 1       0.0  432.150000  432.150000        0.0
# 2       0.0  431.500000  431.500000        0.0
# 3       0.0  427.150000  427.150000        0.0
# 4       0.0  424.870000  424.870000        0.0
# 5       0.0  423.333333  423.333333        0.0
# 6       0.0  421.407143  421.407143        0.0
# 7       0.0  424.543750  424.543750        0.0
# 8       0.0  430.122222  430.122222        0.0
# 9       0.0  436.960000  436.960000        0.0
# 10      0.0  441.290909  441.290909        0.0
# 11      0.0  444.983333  444.983333        0.0
# 12      0.0  448.165385  448.165385        0.0
# 13      0.0  452.500000  452.500000        0.0
# 14      0.0  455.696667  455.696667        0.0
# 15      0.0  458.150000  458.150000        0.0
# 16      0.0  459.847059  459.847059        0.0
# 17      0.0  461.147222  461.147222        0.0
# 18      0.0  462.542105  462.542105        0.0
# ...

# %%
fig = plt.figure(figsize=(20,15))

ax1 = fig.add_subplot(111, ylabel='Price')

voltas['Close Price'].plot(ax=ax1, color='black', lw=2.)

signals[['short_mavg', 'long_mavg']].plot(ax=ax1, lw=2.)

ax1.plot(signals.loc[signals.positions == 1.0].index, signals.short_mavg[signals.positions == 1.0], '^' , markersize=20,color='g')

ax1.plot(signals.loc[signals.positions == -1.0].index, signals.short_mavg[signals.positions == -1.0], 'v' , markersize=20,color='r')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

symbol = 'VOLTAS'

data = pd.read_csv('VOLTAS.csv'.format(symbol), index_col='Date',
                 parse_dates=True, usecols=['Date', 'Close Price'],
                 na_values='nan')

data = data.rename(columns={'Close Price': symbol})
data.dropna(inplace=True)

sma = data.rolling(window=14).mean()

rstd = data.rolling(window=14).std()

upper_band = sma + 2 * rstd
upper_band = upper_band.rename(columns={symbol: 'upper'})
lower_band = sma - 2 * rstd
lower_band = lower_band.rename(columns={symbol: 'lower'})
data = data.join(upper_band).join(lower_band)
ax = data.plot(title='{} Price and BB'.format(symbol))
ax.fill_between(df.index, lower_band['lower'], upper_band['upper'], color='#ADCCFF', alpha='0.4')
ax.set_xlabel('Date')
ax.set_ylabel('SMA and BB')
ax.grid()
plt.show()
